# %% [markdown]
# # Azure ML - Sample Batch Prediction Pipeline

# %% [markdown]
# This notebook demonstrates creation and execution of an Azure ML pipeline designed to load data from a remote source, to make predictions against that data using a previously registered ML model, and finally save that data

# %%
experiment_folder = 'diabetes-inference-pipeline'
cluster_name = "mm-cluster"

# %% [markdown]
# ## Connect to workspace

# %% [markdown]
# ### Import Required Packages

# %%
from azureml.core import Workspace, Experiment, Datastore, Environment, Dataset
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.pipeline.core import Pipeline, PipelineParameter, PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineParameter, PipelineData, PipelineEndpoint
from azureml.data.output_dataset_config import OutputTabularDatasetConfig, OutputDatasetConfig, OutputFileDatasetConfig

# %%
# Connect to AML Workspace
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))

# Get the default datastore
default_ds = ws.get_default_datastore()
# Out:
# Ready to use Azure ML 1.34.0 to work with mm-aml-dev2

# %%
import os
# Create a folder for the pipeline step files
os.makedirs(experiment_folder, exist_ok=True)
print(experiment_folder)
# Out:
# diabetes-inference-pipeline

# %% [markdown]
# ### Create Compute Resources

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

print('trying to create: ' + cluster_name)

try:
    # Check for existing compute target
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2, idle_seconds_before_scaledown=1800)
        compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
        compute_target.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# trying to create: mm-cluster
# Found existing cluster, use it.

# %% [markdown]
# ## Run Configuration
# Create configuration for the running pipeline.  The RunConfiguration defines the environment used in the python steps

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies



run_config = RunConfiguration()
run_config.docker.use_docker = True
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                                                            pip_packages=['azureml-sdk','numpy', 'joblib', 'sklearn' ])

# %% [markdown]
# ## Define Output Datasets
#
# Below are the configuration for datasets that will be passed between steps in our pipelien.  Note, in all cases we specifiy the datastore that should hold the datasets and wheather they should be registered following step completion or not.  This can optionally be disabled by removing the register_on_complete() call

# %%
inferencing_dataset = OutputFileDatasetConfig(name= 'diabetes_inferencing_dataset', destination=(default_ds, 'inferencing_dataset/{run-id}')).read_delimited_files().register_on_complete(name= 'pipeline_diabetes_inferencing_data')
scored_dataset      = OutputFileDatasetConfig(name= 'diabetes_scored_dataset', destination=(default_ds, 'scored_dataset/{run-id}')).read_delimited_files().register_on_complete(name=  'pipeline_diabetes_scored_data')

# %% [markdown]
# # Define Pipeline Parameters
#
# PipelineParameter objects serve as variable inputs to an Azure ML pipeline and can be specified at runtime. Multiple pipeline parameters can be created and used. Included here are multiple sample pipeline parameters (get_data_param_*) to highlight how parameters can be passed into and consumed by various pipeline steps.

# %%
inference_data_location_parm = PipelineParameter(name='inference_data_location', default_value= 'diabetes-inference-data')
model_name_parm              = PipelineParameter(name='model_name', default_value= 'diabetes_model')
get_data_param_2             = PipelineParameter(name='get_data_param_2', default_value='value_2')
get_data_param_3             = PipelineParameter(name='get_data_param_3', default_value='value_3')

# %%
import os, shutil
folder_name = 'batch-inferencing'
script_folder = os.path.join(os.getcwd(), folder_name)
print(script_folder)
os.makedirs(script_folder, exist_ok=True)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/memasanz1/code/Users/memasanz/AMLHackathonWithMLOps/sourcecode/02_RemotePipeline/batch-inferencing

# %%
# %%writefile $script_folder/get_inferencing_data.py

  
from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.data.datapath import DataPath
import pandas as pd
import os
import argparse


#Parse input arguments
parser = argparse.ArgumentParser("Get Inferencing Data")
parser.add_argument('--inference_data_location', type=str, required=True)
parser.add_argument('--get_data_param_2', type=str, required=True)
parser.add_argument('--get_data_param_3', type=str, required=True)
parser.add_argument('--inferencing_dataset', dest='inferencing_dataset', required=True)

# Note: the get_data_param args below are included only as an example of argument passing.
# They are not consumed in the code sample shown here.
args, _ = parser.parse_known_args()

inference_data_location = args.inference_data_location
get_data_param_2 = args.get_data_param_2
get_data_param_3 = args.get_data_param_3
inferencing_dataset = args.inferencing_dataset

print(str(type(inferencing_dataset)))
print(inferencing_dataset)

#Get current run
current_run = Run.get_context()

#Get associated AML workspace
ws = current_run.experiment.workspace

#Get default datastore
ds = ws.get_default_datastore()

# Get the default datastore
default_ds = ws.get_default_datastore()

tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, inference_data_location + '/*.csv'))

# Register the tabular dataset
try:
    tab_data_set = tab_data_set.register(workspace=ws, 
                                name= 'diabetes-tabular-dataset-raw',
                                description='diabetes data',
                                tags = {'format':'csv'},
                                create_new_version=True)
    print('Dataset registered.')
except Exception as ex:
        print(ex)
        
df = tab_data_set.to_pandas_dataframe()

print('dataset shape = ' + str(df.shape))
print('saving inferencing data: ' + inferencing_dataset)

# Save dataset for consumption in next pipeline step
os.makedirs(inferencing_dataset, exist_ok=True)
df.to_csv(os.path.join(inferencing_dataset, 'inferencing_data.csv'), index=False)
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/memasanz1/code/Users/memasanz/AMLHackathonWithMLOps/sourcecode/02_RemotePipeline/batch-inferencing/get_inferencing_data.py

# %%
# %%writefile $script_folder/score_inferencing_data.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.core.model import Model
from azureml.data.datapath import DataPath
import pandas as pd
import os
import argparse
import joblib
import json
import joblib
import numpy as np
from azureml.core.model import Model
import time
import pandas as pd
import azureml.core
from azureml.core import Workspace, Dataset
import os
import math


# Parse input arguments
parser = argparse.ArgumentParser("Score Inferencing Data")
parser.add_argument('--model_name_parm', type=str, required=True)
parser.add_argument('--scored_dataset', dest='scored_dataset', required=True)

args, _ = parser.parse_known_args()
model_name = args.model_name_parm
scored_dataset = args.scored_dataset

# Get current run
current_run = Run.get_context()

# Get associated AML workspace
ws = current_run.experiment.workspace

# Get default datastore
ds = ws.get_default_datastore()


inferencing_dataset = current_run.input_datasets['diabetes_inferencing_data']
inferencing_data_df = inferencing_dataset.to_pandas_dataframe()


print('inferencing data df shape:' + str(inferencing_data_df.shape))

#drop columns not in model
col_list = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']
inferencing_data_df = inferencing_data_df[col_list]

print('model_name' + model_name)

# Get model from workspace - the code below will always retrieve the latest version of the model; specific versions can be targeted.
model_list = Model.list(ws, name=model_name, latest=True)
model_path = model_list[0].download(exist_ok=True)
model = joblib.load(model_path)


print(inferencing_data_df.shape)


# Make predictions with new dataframe
predictions = model.predict(inferencing_data_df)

print('made predictions')

print(predictions)


inferencing_data_df['Predictions']=predictions

print(inferencing_data_df.head(5))


# Save scored dataset
os.makedirs(scored_dataset, exist_ok=True)
print(scored_dataset)

os.makedirs(scored_dataset, exist_ok=True)
print(scored_dataset)
inferencing_data_df.to_csv(os.path.join(scored_dataset, 'scored_data.csv'), index=False)
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/memasanz1/code/Users/memasanz/AMLHackathonWithMLOps/sourcecode/02_RemotePipeline/batch-inferencing/score_inferencing_data.py

# %%
# %%writefile $script_folder/publish_scored_data.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.data.datapath import DataPath
import pandas as pd
import os
import argparse


# Parse input arguments
# parser = argparse.ArgumentParser("Score Inferencing Data")
# parser.add_argument('--user_param', type=str, required=True)


# args, _ = parser.parse_known_args()
# user = args.user_param



# Get current run
current_run = Run.get_context()

# Get associated AML workspace
ws = current_run.experiment.workspace

# Get default datastore
ds = ws.get_default_datastore()

# Get inferencing dataset
scored_dataset = current_run.input_datasets['diabetes_scored_data']
scored_data_df = scored_dataset.to_pandas_dataframe()

# Save dataset to ./outputs dir
os.makedirs('./outputs', exist_ok=True)
scored_data_df.to_csv(os.path.join('outputs', 'scored_data.csv'), index=False)


# # Save dataset to ./outputs dir
# os.makedirs('./outputs', exist_ok=True)
# scored_data_df.to_parquet(os.path.join('outputs', 'scored_data.parquet'), index=False)
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/memasanz1/code/Users/memasanz/AMLHackathonWithMLOps/sourcecode/02_RemotePipeline/batch-inferencing/publish_scored_data.py

# %%
get_inferencing_data_step = PythonScriptStep(
    name='Get Inferencing Data',
    script_name='get_inferencing_data.py',
    arguments=[
        '--inference_data_location', inference_data_location_parm,
        '--get_data_param_2', get_data_param_2,
        '--get_data_param_3', get_data_param_3,
        '--inferencing_dataset', inferencing_dataset
    ],
    outputs=[inferencing_dataset],
    compute_target=compute_target,
    source_directory=folder_name,
    allow_reuse=False,
    runconfig=run_config
)

score_inferencing_data_step = PythonScriptStep(
    name='Score Inferencing Data',
    script_name='score_inferencing_data.py',
    arguments=[
        '--model_name_parm', model_name_parm,
        '--scored_dataset', scored_dataset
    ],
    inputs=[inferencing_dataset.as_input(name= 'diabetes_inferencing_data')],
    outputs=[scored_dataset],
    compute_target=compute_target,
    source_directory=folder_name,
    allow_reuse=False,
    runconfig=run_config
)

publish_scored_data_step = PythonScriptStep(
    name='Publish Scored Data',
    script_name='publish_scored_data.py',
    inputs=[scored_dataset.as_input(name= 'diabetes_scored_data')],
    compute_target=compute_target,
    source_directory=folder_name,
    allow_reuse=False,
    runconfig=run_config
)

# %% [markdown]
# # Create Pipeline
#
# Create an Azure ML Pipeline by specifying the steps to be executed. Note: based on the dataset dependencies between steps, exection occurs logically such that no step will execute unless all of the necessary input datasets have been generated.

# %%
pipeline = Pipeline(workspace=ws, steps=[get_inferencing_data_step, score_inferencing_data_step, publish_scored_data_step])

# %%
experiment = Experiment(ws,  'diabetes-scoring-experiment')
run = experiment.submit(pipeline)
run.wait_for_completion(show_output=True)
# Out:
# Created step Get Inferencing Data [dc6212c0][00f26b7f-d3be-4930-9f81-c8ca3e089c95], (This step will run and generate new outputs)
# Created step Score Inferencing Data [9b90e2fa][15e7ae8c-83b3-4194-aa58-0e8ba12f7ff6], (This step will run and generate new outputs)
# Created step Publish Scored Data [26f26add][702b5f14-0282-4e95-846e-3bc1363f5348], (This step will run and generate new outputs)
# Submitted PipelineRun 4f8309d7-793c-4421-aa0c-5b34afa57932
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4f8309d7-793c-4421-aa0c-5b34afa57932?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRunId: 4f8309d7-793c-4421-aa0c-5b34afa57932
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4f8309d7-793c-4421-aa0c-5b34afa57932?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRun Status: Running
#
#
# StepRunId: 6ffc42e6-03aa-4ba0-91db-be303573450e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/6ffc42e6-03aa-4ba0-91db-be303573450e?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Get Inferencing Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ========================================================================================================================
# 2021-11-16T16:24:51Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:24:51Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/mounts/workspaceblobstore
# 2021-11-16T16:24:51Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:24:51Z Starting output-watcher...
# 2021-11-16T16:24:51Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-16T16:24:53Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-11-16T16:24:53Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004
# Digest: sha256:e5f370f3f52121d8983c6e663e949e85708ffbe0c7359cefad6507e0f3e9275f
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# 2021-11-16T16:24:55Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:24:55Z Check if container 6ffc42e6-03aa-4ba0-91db-be303573450e_DataSidecar already exist exited with 0,
#
# cc5be55f57f7f435340649e39aee22e7213aa1430f8f149889bcb0f9131b7a1a
# 2021-11-16T16:24:55Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:24:55Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2278fd089ebdd511a7ad3371b3ce66a2-c7efaab1eb281bfe-01 -sshRequired=false]
# 2021/11/16 16:24:55 Got JobInfoJson from env
# 2021/11/16 16:24:55 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:24:55 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:24:55 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:24:55 Starting infiniband setup
# 2021/11/16 16:24:55 Python Version found is Python 3.7.9
#
# 2021/11/16 16:24:55 Returning Python Version as 3.7
# 2021-11-16T16:24:55Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:24:55 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:24:55 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:24:55 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021-11-16T16:24:55Z Not setting up Infiniband in Container
# 2021/11/16 16:24:55 Not setting up Infiniband in Container
# 2021/11/16 16:24:55 Not setting up Infiniband in Container
# 2021/11/16 16:24:55 Python Version found is Python 3.7.9
#
# 2021/11/16 16:24:55 Returning Python Version as 3.7
# 2021/11/16 16:24:55 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:24:56 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:24:56 App Insight Client has already been closed
# 2021/11/16 16:24:56 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:24:56Z Starting docker container succeeded.
# 2021-11-16T16:24:56Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/11/16 16:25:16 Got JobInfoJson from env
# 2021/11/16 16:25:16 Starting App Insight Logger for task:  runTaskLet
# 2021/11/16 16:25:16 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:25:16 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/11/16 16:25:16 Send process info logs to master server succeeded
# 2021/11/16 16:25:16 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/11/16 16:25:16 Send process info logs to master server succeeded
# [2021-11-16T16:25:16.172869] Entering context manager injector.
# [2021-11-16T16:25:16.894654] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['get_inferencing_data.py', '--inference_data_location', 'diabetes-inference-data', '--get_data_param_2', 'value_2', '--get_data_param_3', 'value_3', '--inferencing_dataset', 'DatasetOutputConfig:diabetes_inferencing_dataset'])
# Script type = None
# [2021-11-16T16:25:16.899020] Entering Run History Context Manager.
# [2021-11-16T16:25:18.314386] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e
# [2021-11-16T16:25:18.314672] Preparing to call script [get_inferencing_data.py] with arguments:['--inference_data_location', 'diabetes-inference-data', '--get_data_param_2', 'value_2', '--get_data_param_3', 'value_3', '--inferencing_dataset', '$diabetes_inferencing_dataset']
# [2021-11-16T16:25:18.314708] After variable expansion, calling script [get_inferencing_data.py] with arguments:['--inference_data_location', 'diabetes-inference-data', '--get_data_param_2', 'value_2', '--get_data_param_3', 'value_3', '--inferencing_dataset', '/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/diabetes_inferencing_dataset_workspaceblobstore']
#
# <class 'str'>
# /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/diabetes_inferencing_dataset_workspaceblobstore
# 2021/11/16 16:25:21 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Dataset registered.
# dataset shape = (10000, 10)
# saving inferencing data: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/diabetes_inferencing_dataset_workspaceblobstore
#
#
# [2021-11-16T16:25:28.339318] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
# Cleanup took 0.20425844192504883 seconds
# [2021-11-16T16:25:28.701708] Finished context manager injector.
# 2021/11/16 16:25:36 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/11/16 16:25:36 Send process info logs to master server succeeded
# 2021/11/16 16:25:36 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/11/16 16:25:36 Process Exiting with Code:  0
# 2021/11/16 16:25:36 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# Streaming azureml-logs/75_job_post-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ===============================================================================================================
# [2021-11-16T16:25:37.261257] Entering job release
# [2021-11-16T16:25:38.236517] Starting job release
# [2021-11-16T16:25:38.237365] Logging experiment finalizing status in history service.[2021-11-16T16:25:38.237556] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 227
#
# [2021-11-16T16:25:38.238250] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-16T16:25:38.240568] job release stage : execute_job_release starting...
# [2021-11-16T16:25:38.254508] job release stage : copy_batchai_cached_logs starting...
# [2021-11-16T16:25:38.254962] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:25:38.255679] Entering context manager injector.
# [2021-11-16T16:25:38.273008] job release stage : upload_datastore completed...
# [2021-11-16T16:25:38.339988] job release stage : send_run_telemetry starting...
# [2021-11-16T16:25:38.360617] get vm size and vm region successfully.
# [2021-11-16T16:25:38.376012] get compute meta data successfully.
# [2021-11-16T16:25:38.492255] job release stage : execute_job_release completed...
# [2021-11-16T16:25:38.542406] post artifact meta request successfully.
# [2021-11-16T16:25:38.604402] upload compute record artifact successfully.
# [2021-11-16T16:25:38.604497] job release stage : send_run_telemetry completed...
# [2021-11-16T16:25:38.605049] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-11-16T16:25:38.605211] Running Sidecar release cmd...
# [2021-11-16T16:25:38.618131] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e
# [2021-11-16T16:25:38.631] Enter __exit__ of DatasetContextManager
# [2021-11-16T16:25:38.631] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/diabetes_inferencing_dataset_workspaceblobstore.
# [2021-11-16T16:25:38.667] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/6ffc42e6-03aa-4ba0-91db-be303573450e/wd/diabetes_inferencing_dataset_workspaceblobstore.
# [2021-11-16T16:25:38.667] Exit __exit__ of DatasetContextManager
# [2021-11-16T16:25:38.667407] Removing absolute paths from host...
# [2021-11-16T16:25:38.667733] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-11-16T16:25:39.245825] Ran Sidecar release cmd.
# [2021-11-16T16:25:39.245929] Job release is complete
#
# StepRun(Get Inferencing Data) Execution Summary
# ================================================
# StepRun( Get Inferencing Data ) Status: Finished
# {'runId': '6ffc42e6-03aa-4ba0-91db-be303573450e', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:24:50.611378Z', 'endTimeUtc': '2021-11-16T16:25:49.938723Z', 'services': {}, 'properties': {'ContentSnapshotId': '12be1090-2d64-4781-8e0f-3d2ffe9832ec', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '00f26b7f-d3be-4930-9f81-c8ca3e089c95', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'dc6212c0', 'azureml.pipelinerunid': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipeline': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [{'identifier': {'savedId': '63cfaafe-5f0c-401c-ac6d-ebcd8f2b039b', 'registeredId': '831aed58-93e7-45ff-b034-3e3025491dcd', 'registeredVersion': '2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'diabetes_inferencing_dataset'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'inferencing_dataset/6ffc42e6-03aa-4ba0-91db-be303573450e')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "63cfaafe-5f0c-401c-ac6d-ebcd8f2b039b",
#     "name": "pipeline_diabetes_inferencing_data",
#     "version": 2,
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}, {'identifier': {'savedId': '8fb44e94-769e-495b-90b8-7e93f2d7a034', 'registeredId': '8e651081-2cb2-400d-89c4-f664e360ed05', 'registeredVersion': '1'}, 'outputType': 'Reference', 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'diabetes-inference-data/*.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "8fb44e94-769e-495b-90b8-7e93f2d7a034",
#     "name": "diabetes-tabular-dataset-raw",
#     "version": 1,
#     "description": "diabetes data",
#     "tags": {
#       "format": "csv"
#     },
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}], 'runDefinition': {'script': 'get_inferencing_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--inference_data_location', '$AML_PARAMETER_inference_data_location', '--get_data_param_2', '$AML_PARAMETER_get_data_param_2', '--get_data_param_3', '$AML_PARAMETER_get_data_param_3', '--inferencing_dataset', 'DatasetOutputConfig:diabetes_inferencing_dataset'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {}, 'data': {}, 'outputData': {'diabetes_inferencing_dataset': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'inferencing_dataset/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'pipeline_diabetes_inferencing_data', 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': '{\n  "blocks": [\n    {\n      "id": "b8f67f9e-f2f1-40c2-ac50-aeda1e41e04a",\n      "type": "Microsoft.DPrep.ParseDelimitedBlock",\n      "arguments": {\n        "columnHeadersMode": 3,\n        "fileEncoding": 0,\n        "handleQuotedLineBreaks": false,\n        "preview": false,\n        "separator": ",",\n        "skipRows": 0,\n        "skipRowsMode": 0\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    },\n    {\n      "id": "8d0f4dda-bd91-47c3-a064-7f9dec223f5b",\n      "type": "Microsoft.DPrep.DropColumnsBlock",\n      "arguments": {\n        "columns": {\n          "type": 0,\n          "details": {\n            "selectedColumns": [\n              "Path"\n            ]\n          }\n        }\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    }\n  ],\n  "inspectors": [],\n  "meta": {\n    "steps_added": "2"\n  }\n}'}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment diabetes-scoring-experiment Environment', 'version': 'Autosave_2021-11-16T16:22:15Z_5387c233', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'numpy', 'joblib', 'sklearn']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_324a0b184a068add828a67be987b4b84'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanc ...
# StepRunId: 3511ce41-705c-4428-ae8f-3a161c9fde27
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3511ce41-705c-4428-ae8f-3a161c9fde27?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Score Inferencing Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# ========================================================================================================================
# 2021-11-16T16:27:16Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:27:16Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/mounts/workspaceblobstore
# 2021-11-16T16:27:17Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:17Z Starting output-watcher...
# 2021-11-16T16:27:17Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-16T16:27:17Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-11-16T16:27:17Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004
# Digest: sha256:e5f370f3f52121d8983c6e663e949e85708ffbe0c7359cefad6507e0f3e9275f
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# 2021-11-16T16:27:17Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:18Z Check if container 3511ce41-705c-4428-ae8f-3a161c9fde27_DataSidecar already exist exited with 0,
#
# dac5826fc30766d7665d63d030cfa9d4f6dcd9ad796e5fdb87cfe955f4b3a152
# 2021-11-16T16:27:18Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:27:18Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-fbbcb86dd3822853012c9ed09d292a39-5d1323e164e5b467-01 -sshRequired=false]
# 2021/11/16 16:27:18 Got JobInfoJson from env
# 2021/11/16 16:27:18 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:27:18 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:27:18 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:27:18 Starting infiniband setup
# 2021/11/16 16:27:18 Python Version found is Python 3.7.9
#
# 2021/11/16 16:27:18 Returning Python Version as 3.7
# 2021/11/16 16:27:18 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:27:18 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-11-16T16:27:18Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:27:18 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/11/16 16:27:18 Not setting up Infiniband in Container
# 2021/11/16 16:27:18 Not setting up Infiniband in Container
# 2021-11-16T16:27:18Z Not setting up Infiniband in Container
# 2021/11/16 16:27:18 Python Version found is Python 3.7.9
#
# 2021/11/16 16:27:18 Returning Python Version as 3.7
# 2021/11/16 16:27:18 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:27:18 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:27:18 App Insight Client has already been closed
# 2021/11/16 16:27:18 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:27:18Z Starting docker container succeeded.
# 2021-11-16T16:27:18Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:31Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:32Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:32Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-11-16T16:27:32Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/11/16 16:27:35 Got JobInfoJson from env
# 2021/11/16 16:27:35 Starting App Insight Logger for task:  runTaskLet
# 2021/11/16 16:27:35 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:27:35 Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/info
# 2021/11/16 16:27:35 Send process info logs to master server succeeded
# 2021/11/16 16:27:35 Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/status
# 2021/11/16 16:27:35 Send process info logs to master server succeeded
# [2021-11-16T16:27:35.289114] Entering context manager injector.
# [2021-11-16T16:27:35.943430] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['score_inferencing_data.py', '--model_name_parm', 'diabetes_model', '--scored_dataset', 'DatasetOutputConfig:diabetes_scored_dataset'])
# Script type = None
# [2021-11-16T16:27:35.948331] Entering Run History Context Manager.
# [2021-11-16T16:27:37.346128] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27
# [2021-11-16T16:27:37.346168] Preparing to call script [score_inferencing_data.py] with arguments:['--model_name_parm', 'diabetes_model', '--scored_dataset', '$diabetes_scored_dataset']
# [2021-11-16T16:27:37.346186] After variable expansion, calling script [score_inferencing_data.py] with arguments:['--model_name_parm', 'diabetes_model', '--scored_dataset', '/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/diabetes_scored_dataset_workspaceblobstore']
#
# 2021/11/16 16:27:40 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# inferencing data df shape:(10000, 10)
# model_namediabetes_model
# /azureml-envs/azureml_324a0b184a068add828a67be987b4b84/lib/python3.6/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.2 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# (10000, 8)
# made predictions
# ['0' '0' '0' ... '1' '0' '1']
# score_inferencing_data.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inferencing_data_df['Predictions']=predictions
#   Pregnancies PlasmaGlucose  ... Age Predictions
# 0           0           171  ...  21           0
# 1           8            92  ...  23           0
# 2           7           115  ...  23           0
# 3           9           103  ...  43           1
# 4           1            85  ...  22           0
#
# [5 rows x 9 columns]
# /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/diabetes_scored_dataset_workspaceblobstore
# /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/diabetes_scored_dataset_workspaceblobstore
#
#
# [2021-11-16T16:27:44.534964] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 4 items cleaning up...
# Cleanup took 0.2777266502380371 seconds
# [2021-11-16T16:27:44.956694] Finished context manager injector.
# Streaming azureml-logs/75_job_post-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# ===============================================================================================================
# [2021-11-16T16:27:52.685410] Entering job release
# [2021-11-16T16:27:53.623823] Starting job release
# [2021-11-16T16:27:53.625176] Logging experiment finalizing status in history service.[2021-11-16T16:27:53.625606] job release stage : upload_datastore starting...
#
# Starting the daemon thread to refresh tokens in background for process with pid = 218
# [2021-11-16T16:27:53.626109] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-16T16:27:53.626493] job release stage : execute_job_release starting...
# [2021-11-16T16:27:53.627294] job release stage : copy_batchai_cached_logs starting...
# [2021-11-16T16:27:53.629702] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:27:53.646174] Entering context manager injector.
# [2021-11-16T16:27:53.657666] job release stage : upload_datastore completed...
# [2021-11-16T16:27:53.735818] job release stage : send_run_telemetry starting...
# [2021-11-16T16:27:53.770350] get vm size and vm region successfully.
# [2021-11-16T16:27:53.808306] get compute meta data successfully.
# [2021-11-16T16:27:53.864738] job release stage : execute_job_release completed...
# [2021-11-16T16:27:53.958987] post artifact meta request successfully.
# [2021-11-16T16:27:54.020188] upload compute record artifact successfully.
# [2021-11-16T16:27:54.020267] job release stage : send_run_telemetry completed...
# [2021-11-16T16:27:54.020795] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-11-16T16:27:54.020955] Running Sidecar release cmd...
# [2021-11-16T16:27:54.038301] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27
# [2021-11-16T16:27:54.051] Enter __exit__ of DatasetContextManager
# [2021-11-16T16:27:54.051] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/diabetes_scored_dataset_workspaceblobstore.
# [2021-11-16T16:27:54.093] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/3511ce41-705c-4428-ae8f-3a161c9fde27/wd/diabetes_scored_dataset_workspaceblobstore.
# [2021-11-16T16:27:54.093] Exit __exit__ of DatasetContextManager
# [2021-11-16T16:27:54.093434] Removing absolute paths from host...
# [2021-11-16T16:27:54.093707] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-11-16T16:27:54.371810] Ran Sidecar release cmd.
# [2021-11-16T16:27:54.371896] Job release is complete
#
# StepRun(Score Inferencing Data) Execution Summary
# ==================================================
# StepRun( Score Inferencing Data ) Status: Finished
# {'runId': '3511ce41-705c-4428-ae8f-3a161c9fde27', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:27:15.659362Z', 'endTimeUtc': '2021-11-16T16:28:04.642518Z', 'services': {}, 'properties': {'ContentSnapshotId': '12be1090-2d64-4781-8e0f-3d2ffe9832ec', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '15e7ae8c-83b3-4194-aa58-0e8ba12f7ff6', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9b90e2fa', 'azureml.pipelinerunid': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipeline': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '63cfaafe-5f0c-401c-ac6d-ebcd8f2b039b'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_inferencing_data', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': '2abf0315-480b-4e75-b729-e9730fb2a394', 'registeredId': 'ae6a2865-39c6-4077-a5ea-1cb075087742', 'registeredVersion': '2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'diabetes_scored_dataset'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'scored_dataset/3511ce41-705c-4428-ae8f-3a161c9fde27')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "2abf0315-480b-4e75-b729-e9730fb2a394",
#     "name": "pipeline_diabetes_scored_data",
#     "version": 2,
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}], 'runDefinition': {'script': 'score_inferencing_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--model_name_parm', '$AML_PARAMETER_model_name', '--scored_dataset', 'DatasetOutputConfig:diabetes_scored_dataset'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {}, 'data': {'diabetes_inferencing_data': {'dataLocation': {'dataset': {'id': '63cfaafe-5f0c-401c-ac6d-ebcd8f2b039b', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_inferencing_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'diabetes_scored_dataset': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'scored_dataset/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'pipeline_diabetes_scored_data', 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': '{\n  "blocks": [\n    {\n      "id": "76f87640-a60a-4aa9-a47f-601523c05248",\n      "type": "Microsoft.DPrep.ParseDelimitedBlock",\n      "arguments": {\n        "columnHeadersMode": 3,\n        "fileEncoding": 0,\n        "handleQuotedLineBreaks": false,\n        "preview": false,\n        "separator": ",",\n        "skipRows": 0,\n        "skipRowsMode": 0\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    },\n    {\n      "id": "5130e9e6-660c-447d-acd0-32adcf9187c4",\n      "type": "Microsoft.DPrep.DropColumnsBlock",\n      "arguments": {\n        "columns": {\n          "type": 0,\n          "details": {\n            "selectedColumns": [\n              "Path"\n            ]\n          }\n        }\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    }\n  ],\n  "inspectors": [],\n  "meta": {\n    "steps_added": "2"\n  }\n}'}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment diabetes-scoring-experiment Environment', 'version': 'Autosave_2021-11-16T16:22:15Z_5387c233', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'numpy', 'joblib', 'sklearn']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_324a0b184a068add828a67be987b4b84'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey' ...
# StepRunId: 2bd8cdc0-b354-4f52-8a5a-cc083652d8d6
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Publish Scored Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# ========================================================================================================================
# 2021-11-16T16:28:51Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:28:51Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore
# 2021-11-16T16:28:51Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:51Z Starting output-watcher...
# 2021-11-16T16:28:51Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-16T16:28:51Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-11-16T16:28:51Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_d800048df68f617226e206e10d87110c
# Digest: sha256:4bff2c0f8024270b8deaff73217b2c86a0c452ac71200c94a556228ec1828580
# Status: Image is up to date for 9053afde19bd481fbc9ed12b3864a867.azurecr.io/azureml/azureml_d800048df68f617226e206e10d87110c:latest
# 9053afde19bd481fbc9ed12b3864a867.azurecr.io/azureml/azureml_d800048df68f617226e206e10d87110c:latest
# 2021-11-16T16:28:52Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:52Z Check if container 2bd8cdc0-b354-4f52-8a5a-cc083652d8d6 already exist exited with 0,
#
# 1c4874b7d3760084ba59d4d5f73f24ff833077836f82d7736099a82ba799c4f1
# 2021-11-16T16:28:52Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:28:52Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-85aa91843d468b88c7fb0ee3b2b69363-793a14c1fc24d85e-01 -sshRequired=false]
# 2021/11/16 16:28:52 Got JobInfoJson from env
# 2021/11/16 16:28:52 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:28:52 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:28:52 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:28:52 Starting infiniband setup
# 2021/11/16 16:28:52 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/11/16 16:28:52 Returning Python Version as 3.6
# 2021-11-16T16:28:52Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:28:52 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:28:52 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:28:52 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/11/16 16:28:52 Not setting up Infiniband in Container
# 2021/11/16 16:28:52 Not setting up Infiniband in Container
# 2021-11-16T16:28:52Z Not setting up Infiniband in Container
# 2021/11/16 16:28:52 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/11/16 16:28:52 Returning Python Version as 3.6
# 2021/11/16 16:28:52 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:28:52 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:28:52 App Insight Client has already been closed
# 2021/11/16 16:28:52 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:28:53Z Starting docker container succeeded.
# 2021-11-16T16:28:55Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:55Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:56Z Job environment preparation succeeded on 10.0.0.6. Output:
# >>>   2021/11/16 16:28:50 Got JobInfoJson from env
# >>>   2021/11/16 16:28:50 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/11/16 16:28:50 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# >>>   2021/11/16 16:28:50 Got JobInfoJson from env
# >>>   2021/11/16 16:28:50 runtime.GOOS linux
# >>>   2021/11/16 16:28:50 Checking if '/tmp' exists
# >>>   2021/11/16 16:28:50 Reading dyanamic configs
# >>>   2021/11/16 16:28:50 Container sas url: https://baiscriptswestus2prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=71Fsy25bPMdce8Lc7jVPFZbJokMhH4i%2F250OyAEdREA%3D
# >>>   2021/11/16 16:28:50 Starting Azsecpack installation on machine: 796dd5eb985946b79258d71435a6e3b7000002#72f988bf-86f1-41af-91ab-2d7cd011db47#5da07161-3770-4a4b-aa43-418cbbb627cf#mm-aml-dev2-rg#mm-aml-dev2#mm-cluster#tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d
# >>>   2021/11/16 16:28:50 Azsecpack installation directory: /mnt/batch/tasks/startup/wd/az_resource, Is Azsecpack installer on host: true. Is Azsecpack installation enabled: true,AzSecPack_RoleInstance="diagnosticserver-549456d55b-rqn52"
# >>>   2021/11/16 16:28:50 Is Azsecpack enabled: true, GetDisableVsatlsscan: true
# >>>   2021/11/16 16:28:50 Start preparing environment for azsecpack installation. MachineName is 796dd5eb985946b79258d71435a6e3b7000002
# >>>
# >>>   2021/11/16 16:28:51
# >>>   2021/11/16 16:28:51
# >>>   2021/11/16 16:28:51 bypass systemd resolved
# >>>   2021/11/16 16:28:51 Cluster Subscription Id: 5da07161-3770-4a4b-aa43-418cbbb627cf
# >>>   2021/11/16 16:28:51 Cluster Workspace Name: mm-aml-dev2
# >>>   2021/11/16 16:28:51 Cluster Name: mm-cluster
# >>>   2021/11/16 16:28:51 VMsize: standard_ds11_v2
# >>>   2021/11/16 16:28:51 GPU Count: 0
# >>>   2021/11/16 16:28:51 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/11/16 16:28:51 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:51 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:51 Get GPU count failed with err: The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.,
# >>>   2021/11/16 16:28:51 AMLComputeXDSEndpoint:  https://westus2.cert.api.azureml.ms/xdsbatchai
# >>>   2021/11/16 16:28:51 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/11/16 16:28:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/config
# >>>   2021/11/16 16:28:51 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/11/16 16:28:51 Starting identity responder.
# >>>   2021/11/16 16:28:51 Starting identity responder.
# >>>   2021/11/16 16:28:51 Logfile used for identity responder: /mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/2bd8cdc0-b354-4f52-8_98f77dea-046b-4b88-bbe1-0d687fa33418/IdentityResponderLog-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# >>>   2021/11/16 16:28:51 Logfile used for identity responder: /mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/2bd8cdc0-b354-4f52-8_98f77dea-046b-4b88-bbe1-0d687fa33418/IdentityResponderLog-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# >>>   2021/11/16 16:28:51 Started Identity Responder for job.
# >>>   2021/11/16 16:28:51 Started Identity Responder for job.
# >>>   2021/11/16 16:28:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd
# >>>   2021/11/16 16:28:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/shared
# >>>   2021/11/16 16:28:51 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6
# >>>   2021/11/16 16:28:51 From the policy service, the filtering patterns is: , data store is
# >>>   2021/11/16 16:28:51 Mounting job level file systems
# >>>   2021/11/16 16:28:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts
# >>>   2021/11/16 16:28:51 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/config/.amlcompute.datastorecredentials
# >>>   2021/11/16 16:28:51 Datastore credentials file not found, skipping.
# >>>   2021/11/16 16:28:51 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/config/.master.runtimesastokens
# >>>   2021/11/16 16:28:51 Runtime sas tokens file not found, skipping.
# >>>   2021/11/16 16:28:51 NFS mount is not enabled
# >>>   2021/11/16 16:28:51 No Azure File Shares configured
# >>>   2021/11/16 16:28:51 Mounting blob file systems
# >>>   2021/11/16 16:28:51 Blobfuse runtime version 1.3.6
# >>>   2021/11/16 16:28:51 Mounting azureml-blobstore-9053afde-19bd-481f-bc9e-d12b3864a867 container from mmamldev24709630538 account at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore
# >>>   2021/11/16 16:28:51 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/11/16 16:28:51 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/11/16 16:28:51 Blobfuse cache size set to 18154 MB.
# >>>   2021/11/16 16:28:51 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/11/16 16:28:51 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore
# >>>   2021/11/16 16:28:51 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore
# >>>   2021/11/16 16:28:51 Successfully mounted azureml-blobstore-9053afde-19bd-481f-bc9e-d12b3864a867 container from mmamldev24709630538 account at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore
# >>>   2021/11/16 16:28:51 Failed to created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6, due to mkdir /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6: read-only file system
# >>>   2021/11/16 16:28:51 No unmanaged file systems configured
# >>>   2021/11/16 16:28:51 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:51 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# ...
# >>>   2021/11/16 16:28:53 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/azureml-logs
# >>>   2021/11/16 16:28:53 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/azureml_compute_logs
# >>>   2021/11/16 16:28:53 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_324a0b184a068add828a67be987b4b84/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6-setup/job_prep.py --snapshots '[{"Id":"12be1090-2d64-4781-8e0f-3d2ffe9832ec","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/16 16:28:53 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/azureml_compute_logs/65_job_prep-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# >>>   2021/11/16 16:28:53 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/azureml_compute_logs/65_job_prep-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# >>>   2021/11/16 16:28:53 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/2bd8cdc0-b354-4f52-8_98f77dea-046b-4b88-bbe1-0d687fa33418/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6;/azureml-envs/azureml_324a0b184a068add828a67be987b4b84/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6-setup/job_prep.py --snapshots '[{"Id":"12be1090-2d64-4781-8e0f-3d2ffe9832ec","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/16 16:28:53 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/11/16 16:28:53 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-85aa91843d468b88c7fb0ee3b2b69363-00fc595105950d1e-01 -t 2bd8cdc0-b354-4f52-8a5a-cc083652d8d6 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/2bd8cdc0-b354-4f52-8_98f77dea-046b-4b88-bbe1-0d687fa33418/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/wd/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6;/azureml-envs/azureml_324a0b184a068add828a67be987b4b84/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/mounts/workspaceblobstore/azureml/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6-setup/job_prep.py --snapshots '[{"Id":"12be1090-2d64-4781-8e0f-3d2ffe9832ec","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/16 16:28:55 containerName:2bd8cdc0-b354-4f52-8a5a-cc083652d8d6
# >>>   2021/11/16 16:28:55 sidecar containerName:2bd8cdc0-b354-4f52-8a5a-cc083652d8d6
# >>>   2021/11/16 16:28:55 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/16 16:28:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:55 sidecar dockerLauncher:docker
# >>>   2021/11/16 16:28:55 sidecarContainerId:1c4874b7d3760084ba59d4d5f73f24ff833077836f82d7736099a82ba799c4f1
# >>>   2021/11/16 16:28:55 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/16 16:28:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:28:55 Docker logs for 2bd8cdc0-b354-4f52-8a5a-cc083652d8d6
# >>>
# >>>   2021/11/16 16:28:55 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:53.538889] Entering job preparation.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.013694] Starting job preparation.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.013736] Extracting the control code.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.014193] Starting extract_project.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.014265] Starting to extract zip file.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.034887] Finished extracting zip file.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.038705] Using urllib.request Python 3.0 or later
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.038759] Start fetching snapshots.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.038799] Start fetching snapshot.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.038820] Retrieving project from snapshot: 12be1090-2d64-4781-8e0f-3d2ffe9832ec
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 45
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.224542] Finished fetching snapshot.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.224607] Finished fetching snapshots.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.224633] Finished extract_project.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.224790] Finished fetching and extracting the control code.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.229161] downloadDataStore - Download from datastores if requested.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.230537] Start run_history_prep.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.236528] Entering context manager injector.
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.241561] downloadDataStore completed
# >>>   2021/11/16 16:28:55 runSpecialJobTask: preparation: [2021-11-16T16:28:55.243184] Job preparation is complete.
# >>>   2021/11/16 16:28:55 DockerSideCarContainerLogs:
# >>>
# >>>   2021/11/16 16:28:55 DockerSideCarContainerLogs End
# >>>   2021/11/16 16:28:55 Execution of runSpecialJobTask completed
# >>>   2021/11/16 16:28:55 Attempt 1 of http call to https://westus2.api.azureml.ms/history/v1.0/private/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourceGroups/mm-aml-dev2-rg/providers/Microsoft.MachineLearningServices/workspaces/mm-aml-dev2/runs/2bd8cdc0-b354-4f52-8a5a-cc083652d8d6/spans
# >>>   2021/11/16 16:28:55 Process Exiting with Code:  0
# >>>   2021/11/16 16:28:56 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-11-16T16:28:56Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:56Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:56Z 127.0.0.1 slots=2 max-slots=2
# 2021-11-16T16:28:56Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_85d7b408a10299f214d340817c4b0ee136e4349fd6bb60c5f532d3ff59724335_d.txt
# ===============================================================================================================
# [2021-11-16T16:29:11.170847] Entering job release
# [2021-11-16T16:29:12.724573] Starting job release
# [2021-11-16T16:29:12.726872] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 340
# [2021-11-16T16:29:12.729071] job release stage : upload_datastore starting...
# [2021-11-16T16:29:12.729594] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-16T16:29:12.742700] job release stage : execute_job_release starting...
# [2021-11-16T16:29:12.764153] job release stage : copy_batchai_cached_logs starting...
# [2021-11-16T16:29:12.771926] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:29:12.791526] Entering context manager injector.
# [2021-11-16T16:29:12.794389] job release stage : upload_datastore completed...
# [2021-11-16T16:29:12.877254] job release stage : send_run_telemetry starting...
# [2021-11-16T16:29:12.905698] get vm size and vm region successfully.
# [2021-11-16T16:29:12.938410] get compute meta data successfully.
# [2021-11-16T16:29:13.095541] post artifact meta request successfully.
# [2021-11-16T16:29:13.195300] upload compute record artifact successfully.
# [2021-11-16T16:29:13.195392] job release stage : send_run_telemetry completed...
# [2021-11-16T16:29:13.216532] job release stage : execute_job_release completed...
# [2021-11-16T16:29:13.216886] Job release is complete
#
# StepRun(Publish Scored Data) Execution Summary
# ===============================================
# StepRun( Publish Scored Data ) Status: Finished
# {'runId': '2bd8cdc0-b354-4f52-8a5a-cc083652d8d6', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:28:50.338575Z', 'endTimeUtc': '2021-11-16T16:29:25.006711Z', 'services': {}, 'properties': {'ContentSnapshotId': '12be1090-2d64-4781-8e0f-3d2ffe9832ec', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '702b5f14-0282-4e95-846e-3bc1363f5348', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '26f26add', 'azureml.pipelinerunid': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipeline': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '2abf0315-480b-4e75-b729-e9730fb2a394'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_scored_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'publish_scored_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': [], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {}, 'data': {'diabetes_scored_data': {'dataLocation': {'dataset': {'id': '2abf0315-480b-4e75-b729-e9730fb2a394', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_scored_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment diabetes-scoring-experiment Environment', 'version': 'Autosave_2021-11-16T16:22:15Z_5387c233', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'numpy', 'joblib', 'sklearn']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_324a0b184a068add828a67be987b4b84'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'ret ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4f8309d7-793c-4421-aa0c-5b34afa57932', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:22:12.814932Z', 'endTimeUtc': '2021-11-16T16:29:26.096755Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"inference_data_location":"diabetes-inference-data","get_data_param_2":"value_2","get_data_param_3":"value_3","model_name":"diabetes_model"}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.4f8309d7-793c-4421-aa0c-5b34afa57932/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=XMwbCXsgL%2BaCU%2BulP4hdFWauO9Z3IZP9%2FsJt819bbZ4%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A27Z&se=2021-11-17T00%3A29%3A27Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.4f8309d7-793c-4421-aa0c-5b34afa57932/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Ao84riczQvNqywlXFBgXK4EinkhjdN7bbhH91b1gC4E%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A27Z&se=2021-11-17T00%3A29%3A27Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.4f8309d7-793c-4421-aa0c-5b34afa57932/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=tHRl36QpSdtQczNu%2B%2BlZZCwS4dEURAs%2FceoYBBsRSOs%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A27Z&se=2021-11-17T00%3A29%3A27Z&sp=r'}, 'submittedBy': 'Megan Masanz'}
# 'Finished'

# %% [markdown]
# # Publish Pipeline
#
# Create a published version of pipeline that can be triggered via a REST API call

# %%
published_pipeline = pipeline.publish(name = 'Diabetes Batch Inferencing Pipeline',
                                     description = 'Pipeline that generates batch predictions using a registered trained model.',
                                     continue_on_step_failure = False)

# %%
published_pipeline
# Out:
# Pipeline(Name: Diabetes Batch Inferencing Pipeline,
# Id: cd49b2b1-95df-42d4-90f9-d0b0d8eb772d,
# Status: Active,
# Endpoint: https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourceGroups/mm-aml-dev2-rg/providers/Microsoft.MachineLearningServices/workspaces/mm-aml-dev2/PipelineRuns/PipelineSubmit/cd49b2b1-95df-42d4-90f9-d0b0d8eb772d)

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourceGroups/mm-aml-dev2-rg/providers/Microsoft.MachineLearningServices/workspaces/mm-aml-dev2/PipelineRuns/PipelineSubmit/cd49b2b1-95df-42d4-90f9-d0b0d8eb772d

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": user + "rest-api-diabetes-batch"})
run_id = response.json()["Id"]
run_id

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments[user + "rest-api-diabetes-batch"], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
