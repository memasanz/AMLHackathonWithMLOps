# %% [markdown]
# ## MLOps with Azure ML Pipelines
#
# ML Pipeline - Training & Registration.  ML Pipelines can help you to build, optimize and manage your machine learning workflow.
#
# ML Pipelines encapsulate a workflow for a machine learning task.  Tasks often include:
# - Data Prep
# - Training
# - Publishing Models
# - Deployment of Models
#
# First we will set some key variables to be leveraged inside the notebook

# %%
registered_env_name = "experiment_env"
experiment_folder = 'exp_pipeline'
dataset_prefix_name = 'exp'
cluster_name = "mm-cluster"

# %% [markdown]
# Import required packages

# %%
# Import required packages
from azureml.core import Workspace, Experiment, Datastore, Environment, Dataset
from azureml.core.compute import ComputeTarget, AmlCompute, DataFactoryCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.pipeline.core import Pipeline, PipelineParameter, PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineParameter, PipelineData
from azureml.data.output_dataset_config import OutputTabularDatasetConfig, OutputDatasetConfig, OutputFileDatasetConfig
from azureml.data.datapath import DataPath
from azureml.data.data_reference import DataReference
from azureml.data.sql_data_reference import SqlDataReference
from azureml.pipeline.steps import DataTransferStep
import logging

# %% [markdown]
# ### Connect to the workspace and create a cluster for running the AML Pipeline
#
# Connect to the AML workspace and the default datastore. To run an AML Pipeline, we will want to create compute if a compute cluster is not already available

# %%
# Connect to AML Workspace
ws = Workspace.from_config()

# Get the default datastore
default_ds = ws.get_default_datastore()

#Select AML Compute Cluster
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException


try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create Run configuration
#
# The RunConfiguration defines the environment used across all the python steps.  There are a variety of ways of setting up an environment.  An environment holds the required python packages needed for your code to execute on a compute cluster

# %%
conda_yml_file = '../configuration/environment.yml'

# %%
# %%writefile $conda_yml_file
# name: experiment_env
# dependencies:
# - python=3.6.2
# - scikit-learn
# - ipykernel
# - matplotlib
# - pandas
# - pip
# - pip:
#   - azureml-defaults
#   - pyarrow
# Out:
# Overwriting ../configuration/environment.yml

# %%
# Create a Python environment for the experiment (from a .yml file)
env = Environment.from_conda_specification("experiment_env", conda_yml_file)


run_config = RunConfiguration()
run_config.docker.use_docker = True
run_config.environment = env
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# %%
import os
# Create a folder for the pipeline step files
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# exp_pipeline

# %%
registered_env_name
# Out:
# 'experiment_env'

# %%
from azureml.core import Environment
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment (from a .yml file)
experiment_env = Environment.from_conda_specification(registered_env_name, conda_yml_file)

# Register the environment 
experiment_env.register(workspace=ws)
registered_env = Environment.get(ws, registered_env_name)

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Define Output datasets
#
#
# The **OutputFileDatasetConfig** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you need to pass it as a script argument so your code can access the datastore location referenced by the data reference.
#
# Note, in all cases we specify the datastore that should hold the datasets and whether they should be registered following step completion or not. This can optionally be disabled by removing the register_on_complete() call.
#
# These can be viewed in the Datasets tab directly in the AML Portal

# %%
#get data from storage location and save to exp_raw_data
exp_raw_data       = OutputFileDatasetConfig(name='Exp_Raw_Data', destination=(default_ds, dataset_prefix_name + '_raw_data/{run-id}')).read_delimited_files().register_on_complete(name= dataset_prefix_name + '_Raw_Data')

#data split into testing and training
exp_training_data  = OutputFileDatasetConfig(name='Exp_Training_Data', destination=(default_ds, dataset_prefix_name + '_training_data/{run-id}')).read_delimited_files().register_on_complete(name=dataset_prefix_name + '_Training_Data')
exp_testing_data   = OutputFileDatasetConfig(name='Exp_Testing_Data', destination=(default_ds, dataset_prefix_name + '_testing_data/{run-id}')).read_delimited_files().register_on_complete(name=dataset_prefix_name + '_Testing_Data')

# %% [markdown]
# ## Define Pipeline Data
#
# Data used in pipeline can be **produced by one step** and **consumed in another step** by providing a PipelineData object as an output of one step and an input of one or more subsequent steps
#
# This can be leveraged for moving a model from one step into another for model evaluation

# %%
exp_trained_model_pipeline_data = PipelineData(name='exp_trained_model_pipeline_data', datastore=default_ds)

# %%
# %%writefile ./$experiment_folder/get_data.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.data.datapath import DataPath
import pandas as pd
import os
import argparse
from sklearn import preprocessing
import numpy as np

#Parse input arguments
#command-line parsing module 
parser = argparse.ArgumentParser("Get data from and register in AML workspace")
parser.add_argument('--exp_raw_data', dest='exp_raw_data', required=True)

args, _ = parser.parse_known_args()
exp_raw_dataset = args.exp_raw_data

#Get current run
current_run = Run.get_context()

#Get associated AML workspace
ws = current_run.experiment.workspace

#Connect to default data store
ds = ws.get_default_datastore()

tab_data_set = Dataset.Tabular.from_delimited_files(path=(ds, 'diabetes-data/*.csv'))

raw_df = tab_data_set.to_pandas_dataframe()

#Make directory on mounted storage
os.makedirs(exp_raw_dataset, exist_ok=True)

#this will allow us to register the dataset on completion
raw_df.to_csv(os.path.join(exp_raw_dataset, 'exp_raw_data.csv'), index=False)
# Out:
# Overwriting ./exp_pipeline/get_data.py

# %%
# %%writefile ./$experiment_folder/split.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.data.datapath import DataPath
import os
import argparse

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import joblib
from numpy.random import seed

#Parse input arguments
parser = argparse.ArgumentParser("Split raw data into train/test and scale appropriately")

parser.add_argument('--exp_training_data', dest='exp_training_data', required=True)
parser.add_argument('--exp_testing_data', dest='exp_testing_data', required=True)


args, _ = parser.parse_known_args()
exp_training_data = args.exp_training_data
exp_testing_data = args.exp_testing_data


#Get current run
current_run = Run.get_context()

#Get associated AML workspace
ws = current_run.experiment.workspace

# Read input dataset to pandas dataframe
raw_datset = current_run.input_datasets['Exp_Raw_Data']
raw_df = raw_datset.to_pandas_dataframe()


for col in raw_df.columns:
    missing = raw_df[col].isnull()
    num_missing = np.sum(missing)
    if num_missing > 0:  
        raw_df['quality_{}_ismissing'.format(col)] = missing


print(raw_df.columns)

#Split data into training set and test set
df_train, df_test = train_test_split(raw_df, test_size=0.3, random_state=0)





# Save train data to both train and test (reflects the usage pattern in this sample. Note: test/train sets are typically distinct data).
os.makedirs(exp_training_data, exist_ok=True)
os.makedirs(exp_testing_data, exist_ok=True)

df_train.to_csv(os.path.join(exp_training_data, 'exp_training_data.csv'), index=False)
df_test.to_csv(os.path.join(exp_testing_data, 'exp_testing_data.csv'), index=False)
# Out:
# Overwriting ./exp_pipeline/split.py

# %%
# %%writefile ./$experiment_folder/train.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.data.datapath import DataPath
import os
import argparse
import shutil

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve


import matplotlib.pyplot as plt
import joblib
from numpy.random import seed


#Parse input arguments
parser = argparse.ArgumentParser("Train Logistic Regression model")
parser.add_argument('--exp_trained_model_pipeline_data', dest='exp_trained_model_pipeline_data', required=True)

args, _ = parser.parse_known_args()
exp_trained_model_pipeline_data = args.exp_trained_model_pipeline_data

#Get current run
run = Run.get_context()

#Get associated AML workspace
ws = run.experiment.workspace

# Read input dataset to pandas dataframe
X_train_dataset = run.input_datasets['Exp_Training_Data'].to_pandas_dataframe()
X_test_dataset = run.input_datasets['Exp_Testing_Data'].to_pandas_dataframe()

print(type(X_train_dataset))

# Separate features and labels
X_train, y_train = X_train_dataset[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, X_train_dataset['Diabetic'].values
X_test, y_test   = X_test_dataset[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, X_test_dataset['Diabetic'].values



# Set regularization hyperparameter
reg = 0.01

# Train a logistic regression model
print('Training a logistic regression model with regularization rate of', reg)
run.log('Regularization Rate',  np.float(reg))
model = LogisticRegression(C=1/reg, solver="liblinear").fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

run.parent.log(name='AUC', value=np.float(auc))
run.parent.log(name='Accuracy', value=np.float(acc))

# Save the trained model in the outputs folder
os.makedirs('./outputs', exist_ok=True)
joblib.dump(value=model, filename='./outputs/diabetes_model.pkl')

#df_train.to_csv(os.path.join(exp_training_data, 'exp_training_data.csv'), index=False)
os.makedirs(exp_trained_model_pipeline_data, exist_ok=True)

shutil.copyfile('./outputs/diabetes_model.pkl', os.path.join(exp_trained_model_pipeline_data, 'diabetes_model.pkl'))
# Out:
# Overwriting ./exp_pipeline/train.py

# %%
# %%writefile ./$experiment_folder/evaluate_and_register.py

from azureml.core import Run, Workspace, Datastore, Dataset
from azureml.core.model import Model
from azureml.data.datapath import DataPath

import os
import argparse
import shutil

parser = argparse.ArgumentParser("Evaluate model and register if more performant")
parser.add_argument('--exp_trained_model_pipeline_data', type=str, required=True)

args, _ = parser.parse_known_args()
exp_trained_model_pipeline_data = args.exp_trained_model_pipeline_data


#Get current run
run = Run.get_context()

#Get associated AML workspace
ws = run.experiment.workspace

#Get default datastore
ds = ws.get_default_datastore()

#Get metrics associated with current parent run
metrics = run.get_metrics()

print('current run metrics')
for key in metrics.keys():
        print(key, metrics.get(key))
print('\n')


print('parent run metrics')
#Get metrics associated with current parent run
metrics = run.parent.get_metrics()

for key in metrics.keys():
        print(key, metrics.get(key))
print('\n')

current_model_AUC = float(metrics['AUC'])
current_model_accuracy = float(metrics['Accuracy'])

# Get current model from workspace
model_name = 'diabetes_model'
model_description = 'Diabetes model'
model_list = Model.list(ws, name=model_name, latest=True)
first_registration = len(model_list)==0

updated_tags = {'AUC': current_model_AUC}

print('updated tags')
print(updated_tags)

# Copy autoencoder training outputs to relative path for registration
relative_model_path = 'model_files'
run.upload_folder(name=relative_model_path, path=exp_trained_model_pipeline_data)


#If no model exists register the current model
if first_registration:
    print('First model registration.')
    #model = run.register_model(model_name, model_path='model_files', description=model_description, model_framework='sklearn', model_framework_version=tf.__version__, tags=updated_tags, datasets=formatted_datasets, sample_input_dataset = training_dataset)
    run.register_model(model_path=relative_model_path, model_name='diabetes_model',
                   tags=updated_tags,
                   properties={'AUC': current_model_AUC})
else:
    #If a model has been registered previously, check to see if current model 
    #performs better. If so, register it.
    print(dir(model_list[0]))
    if float(model_list[0].tags['AUC']) < current_model_AUC:
        print('New model performs better than existing model. Register it.')
        #model = run.register_model(model_name, model_path='model_files', description=model_description, model_framework='Tensorflow/Keras', model_framework_version=tf.__version__, tags=updated_tags, datasets=formatted_datasets, sample_input_dataset = training_dataset)
        run.register_model(model_path=relative_model_path, model_name='diabetes_model',
                   tags=updated_tags,
                   properties={'AUC': current_model_AUC, 'Accuracy': current_model_accuracy})
    else:
        print('New model does not perform better than existing model. Cancel run.')
        run.cancel()
# Out:
# Overwriting ./exp_pipeline/evaluate_and_register.py

# %% [markdown]
# ## Create Pipeline steps

# %%
#Get raw data from registered
#Register tabular dataset after retrieval
get_data_step = PythonScriptStep(
    name='Get Data',
    script_name='get_data.py',
    arguments =['--exp_raw_data', exp_raw_data],
    outputs=[exp_raw_data],
    compute_target=pipeline_cluster,
    source_directory='./' + experiment_folder,
    allow_reuse=False,
    runconfig=run_config
)

#Normalize the raw data using a MinMaxScaler
#and then split into test and train datasets
split_scale_step = PythonScriptStep(
    name='Split  Raw Data',
    script_name='split.py',
    arguments =['--exp_training_data', exp_training_data,
                '--exp_testing_data', exp_testing_data],
    inputs=[exp_raw_data.as_input(name='Exp_Raw_Data')],
    outputs=[exp_training_data, exp_testing_data],
    compute_target=pipeline_cluster,
    source_directory='./' + experiment_folder,
    allow_reuse=False,
    runconfig=run_config
)

#Train autoencoder using raw data as an input
#Raw data will be preprocessed and registered as train/test datasets
#Scaler and train autoencoder will be saved out
train_model_step = PythonScriptStep(
    name='Train',
    script_name='train.py',
    arguments =['--exp_trained_model_pipeline_data', exp_trained_model_pipeline_data],
    inputs=[exp_training_data.as_input(name='Exp_Training_Data'),
            exp_testing_data.as_input(name='Exp_Testing_Data'),
           ],
    outputs=[exp_trained_model_pipeline_data],
    compute_target=pipeline_cluster,
    source_directory='./' + experiment_folder,
    allow_reuse=False,
    runconfig=run_config
)

#Evaluate and register model here
#Compare metrics from current model and register if better than current
#best model
evaluate_and_register_step = PythonScriptStep(
    name='Evaluate and Register Model',
    script_name='evaluate_and_register.py',
    arguments=['--exp_trained_model_pipeline_data', exp_trained_model_pipeline_data],
    inputs=[ exp_trained_model_pipeline_data.as_input('exp_trained_model_pipeline_data')],
    compute_target=pipeline_cluster,
    source_directory='./' + experiment_folder,
    allow_reuse=False,
    runconfig=run_config
)

# %% [markdown]
# ## Create Pipeline
# Create an Azure ML Pipeline by specifying the steps to be executed. Note: based on the dataset dependencies between steps, exection occurs logically such that no step will execute unless all of the necessary input datasets have been generated.

# %%
pipeline = Pipeline(workspace=ws, steps=[get_data_step, split_scale_step, train_model_step, evaluate_and_register_step])

# %%
experiment = Experiment(ws, 'diabetes-train-experiment')
run = experiment.submit(pipeline)
run.wait_for_completion(show_output=True)
# Out:
# Created step Get Data [c9140548][855f2e6a-6cc1-4d65-bfe9-afb28cf08bd7], (This step will run and generate new outputs)
# Created step Split  Raw Data [f6fec1b6][ad76a5ff-69b9-461a-b507-d8cd2af282ed], (This step will run and generate new outputs)
# Created step Train [1c0dfdb4][4ba6d523-f90a-4224-a202-8f5bb9f6deed], (This step will run and generate new outputs)
# Created step Evaluate and Register Model [bb29b2a5][fcb4ca5c-4d2a-4dc1-b6d4-87e1687ed0e4], (This step will run and generate new outputs)
# Submitted PipelineRun 353eb952-7a5a-4315-b01c-93e38bcd2b56
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/353eb952-7a5a-4315-b01c-93e38bcd2b56?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRunId: 353eb952-7a5a-4315-b01c-93e38bcd2b56
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/353eb952-7a5a-4315-b01c-93e38bcd2b56?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRun Status: Running
#
#
# StepRunId: f500dd57-9459-4be1-a7b3-2dc03cd8c16a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f500dd57-9459-4be1-a7b3-2dc03cd8c16a?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Get Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ========================================================================================================================
# 2021-11-16T16:23:14Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=20269 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:23:14Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/mounts/workspaceblobstore
# 2021-11-16T16:23:15Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:23:15Z Starting output-watcher...
# 2021-11-16T16:23:15Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-16T16:23:15Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-11-16T16:23:15Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004
# Digest: sha256:e5f370f3f52121d8983c6e663e949e85708ffbe0c7359cefad6507e0f3e9275f
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# 2021-11-16T16:23:16Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:23:16Z Check if container f500dd57-9459-4be1-a7b3-2dc03cd8c16a_DataSidecar already exist exited with 0,
#
# 345924f0ed60d16e250c235cf7ca3f1be889917d4958de150f34050688dfdd94
# 2021-11-16T16:23:16Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:23:16Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-4c9fdc181fc7a06cdeabf452fee34830-dc833fe4ccdddd6f-01 -sshRequired=false]
# 2021/11/16 16:23:16 Got JobInfoJson from env
# 2021/11/16 16:23:16 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:23:16 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:23:16 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:23:16 Starting infiniband setup
# 2021/11/16 16:23:16 Python Version found is Python 3.7.9
#
# 2021/11/16 16:23:16 Returning Python Version as 3.7
# 2021/11/16 16:23:16 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:23:16 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-11-16T16:23:16Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:23:16 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/11/16 16:23:16 Not setting up Infiniband in Container
# 2021/11/16 16:23:16 Not setting up Infiniband in Container
# 2021-11-16T16:23:16Z Not setting up Infiniband in Container
# 2021/11/16 16:23:16 Python Version found is Python 3.7.9
#
# 2021/11/16 16:23:16 Returning Python Version as 3.7
# 2021/11/16 16:23:16 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:23:17 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:23:17 App Insight Client has already been closed
# 2021/11/16 16:23:17 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:23:17Z Starting docker container succeeded.
# 2021-11-16T16:23:17Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ===============================================================================================================
# [2021-11-16T16:23:19.871363] Entering job preparation.
# [2021-11-16T16:23:20.590151] Starting job preparation.
# [2021-11-16T16:23:20.590194] Extracting the control code.
# [2021-11-16T16:23:20.590797] Starting extract_project.
# [2021-11-16T16:23:20.591035] Starting to extract zip file.
# [2021-11-16T16:23:20.615451] Finished extracting zip file.
# [2021-11-16T16:23:20.619231] Using urllib.request Python 3.0 or later
# [2021-11-16T16:23:20.619278] Start fetching snapshots.
# [2021-11-16T16:23:20.619315] Start fetching snapshot.
# [2021-11-16T16:23:20.619332] Retrieving project from snapshot: 7d8c19dd-2959-4a2c-a48d-383b8771e621
# Starting the daemon thread to refresh tokens in background for process with pid = 52
# [2021-11-16T16:23:20.949626] Finished fetching snapshot.
# [2021-11-16T16:23:20.949670] Finished fetching snapshots.
# [2021-11-16T16:23:20.949696] Finished extract_project.
# [2021-11-16T16:23:20.949817] Finished fetching and extracting the control code.
# [2021-11-16T16:23:20.957619] Start run_history_prep.
# [2021-11-16T16:23:20.965597] Job preparation is complete.
# [2021-11-16T16:23:20.965900] Entering Data Context Managers in Sidecar
# [2021-11-16T16:23:20.966905] Running Sidecar prep cmd...
# [2021-11-16T16:23:21.427084] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a
# [2021-11-16T16:23:21.427780] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2021-11-16T16:23:21.649] Enter __enter__ of DatasetContextManager
# [2021-11-16T16:23:21.650] SDK version: azureml-core==1.35.0 azureml-dataprep==2.24.0. Session id: 6ed77c18-ecc0-4ebb-82f7-1c90f19635b8. Run id: f500dd57-9459-4be1-a7b3-2dc03cd8c16a.
# [2021-11-16T16:23:21.650] Processing 'Exp_Raw_Data'.
# [2021-11-16T16:23:21.650] Mode: 'mount'.
# [2021-11-16T16:23:21.650] Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore'.
# [2021-11-16T16:23:24.036] Outputting a tabular dataset: 'True'.
# [2021-11-16T16:23:24.037] Additional Transformation has partition format: 'False'.
# [2021-11-16T16:23:24.680] Mounting Exp_Raw_Data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore.
# [2021-11-16T16:23:29.755] Mounted Exp_Raw_Data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore.
# [2021-11-16T16:23:29.791] Exit __enter__ of DatasetContextManager
# Set OutputDataset Exp_Raw_Data's target path to /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore
# [2021-11-16T16:23:29.791834] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-11-16T16:23:30.498684] Ran Sidecar prep cmd.
# [2021-11-16T16:23:30.499340] Running Context Managers in Sidecar complete.
# Streaming azureml-logs/75_job_post-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ===============================================================================================================
# [2021-11-16T16:24:34.939925] Entering job release
# [2021-11-16T16:24:35.898473] Starting job release
# [2021-11-16T16:24:35.899458] Logging experiment finalizing status in history service.[2021-11-16T16:24:35.899766] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 239
#
# [2021-11-16T16:24:35.904629] Entering context manager injector.
# [2021-11-16T16:24:35.907506] job release stage : upload_datastore completed...
# [2021-11-16T16:24:35.907786] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-16T16:24:35.908045] job release stage : execute_job_release starting...
# [2021-11-16T16:24:35.930232] job release stage : copy_batchai_cached_logs starting...
# [2021-11-16T16:24:35.930875] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:24:36.020232] job release stage : send_run_telemetry starting...
# [2021-11-16T16:24:36.052498] get vm size and vm region successfully.
# [2021-11-16T16:24:36.080728] get compute meta data successfully.
# [2021-11-16T16:24:36.166542] job release stage : execute_job_release completed...
# [2021-11-16T16:24:36.238442] post artifact meta request successfully.
# [2021-11-16T16:24:36.287083] upload compute record artifact successfully.
# [2021-11-16T16:24:36.287168] job release stage : send_run_telemetry completed...
# [2021-11-16T16:24:36.287599] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-11-16T16:24:36.287691] Running Sidecar release cmd...
# [2021-11-16T16:24:36.305132] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a
# [2021-11-16T16:24:36.317] Enter __exit__ of DatasetContextManager
# [2021-11-16T16:24:36.317] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore.
# [2021-11-16T16:24:36.352] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/f500dd57-9459-4be1-a7b3-2dc03cd8c16a/wd/Exp_Raw_Data_workspaceblobstore.
# [2021-11-16T16:24:36.352] Exit __exit__ of DatasetContextManager
# [2021-11-16T16:24:36.352382] Removing absolute paths from host...
# [2021-11-16T16:24:36.352598] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-11-16T16:24:36.561044] Ran Sidecar release cmd.
# [2021-11-16T16:24:36.561146] Job release is complete
#
# StepRun(Get Data) Execution Summary
# ====================================
# StepRun( Get Data ) Status: Finished
# {'runId': 'f500dd57-9459-4be1-a7b3-2dc03cd8c16a', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:23:13.839427Z', 'endTimeUtc': '2021-11-16T16:24:47.534812Z', 'services': {}, 'properties': {'ContentSnapshotId': '7d8c19dd-2959-4a2c-a48d-383b8771e621', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '855f2e6a-6cc1-4d65-bfe9-afb28cf08bd7', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'c9140548', 'azureml.pipelinerunid': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipeline': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [{'identifier': {'savedId': '6f49cc1b-22b4-45d3-ac07-ee58fb43fb13', 'registeredId': 'a5ba85e7-4709-444f-b6ac-3bb1fb3f6042', 'registeredVersion': '2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'Exp_Raw_Data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'exp_raw_data/f500dd57-9459-4be1-a7b3-2dc03cd8c16a')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "6f49cc1b-22b4-45d3-ac07-ee58fb43fb13",
#     "name": "exp_Raw_Data",
#     "version": 2,
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}], 'runDefinition': {'script': 'get_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--exp_raw_data', 'DatasetOutputConfig:Exp_Raw_Data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {}, 'data': {}, 'outputData': {'Exp_Raw_Data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'exp_raw_data/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'exp_Raw_Data', 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': '{\n  "blocks": [\n    {\n      "id": "9342c053-2b72-47f1-ad36-63ed92b02423",\n      "type": "Microsoft.DPrep.ParseDelimitedBlock",\n      "arguments": {\n        "columnHeadersMode": 3,\n        "fileEncoding": 0,\n        "handleQuotedLineBreaks": false,\n        "preview": false,\n        "separator": ",",\n        "skipRows": 0,\n        "skipRowsMode": 0\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    },\n    {\n      "id": "c85d1ba7-e5f1-46a8-bc1e-b820ae652f22",\n      "type": "Microsoft.DPrep.DropColumnsBlock",\n      "arguments": {\n        "columns": {\n          "type": 0,\n          "details": {\n            "selectedColumns": [\n              "Path"\n            ]\n          }\n        }\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    }\n  ],\n  "inspectors": [],\n  "meta": {\n    "steps_added": "2"\n  }\n}'}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}], 'name': 'azureml_0c5a9aa2def4b3c2501c1f40287a356b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'c ...
# StepRunId: 2dfc3702-d486-4ced-b6f6-1d4193a55c82
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2dfc3702-d486-4ced-b6f6-1d4193a55c82?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Split  Raw Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ========================================================================================================================
# 2021-11-16T16:25:56Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:25:56Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/mounts/workspaceblobstore
# 2021-11-16T16:25:57Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:25:57Z Starting output-watcher...
# 2021-11-16T16:25:58Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-11-16T16:25:58Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2021-11-16T16:25:58Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004
# Digest: sha256:e5f370f3f52121d8983c6e663e949e85708ffbe0c7359cefad6507e0f3e9275f
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# viennaglobal.azurecr.io/azureml/azureml_52f4e59ea333871b9a1a7bbc103d3004:latest
# 2021-11-16T16:25:58Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:25:59Z Check if container 2dfc3702-d486-4ced-b6f6-1d4193a55c82_DataSidecar already exist exited with 0,
#
# 1698dd32ed38f12c8b144b9d47b9738ea55e578d82b009fe523d83e8bd400c0f
# 2021-11-16T16:25:59Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:25:59Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e6d466cda351d8fbc0934715f8574557-1781a72a767d33a1-01 -sshRequired=false]
# 2021/11/16 16:25:59 Didn't get JobInfoJson from env, now read from file
# 2021/11/16 16:25:59 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:25:59 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:25:59 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:25:59 Starting infiniband setup
# 2021/11/16 16:25:59 Python Version found is Python 3.7.9
#
# 2021/11/16 16:25:59 Returning Python Version as 3.7
# 2021/11/16 16:25:59 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:25:59 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-11-16T16:25:59Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/11/16 16:25:59 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/11/16 16:25:59 Not setting up Infiniband in Container
# 2021/11/16 16:25:59 Not setting up Infiniband in Container
# 2021-11-16T16:25:59Z Not setting up Infiniband in Container
# 2021/11/16 16:25:59 Python Version found is Python 3.7.9
#
# 2021/11/16 16:25:59 Returning Python Version as 3.7
# 2021/11/16 16:25:59 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:26:00 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:26:00 App Insight Client has already been closed
# 2021/11/16 16:26:00 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:26:00Z Starting docker container succeeded.
# 2021-11-16T16:26:00Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/11/16 16:26:22 Didn't get JobInfoJson from env, now read from file
# 2021/11/16 16:26:23 Starting App Insight Logger for task:  runTaskLet
# 2021/11/16 16:26:23 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:26:23 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/11/16 16:26:23 Send process info logs to master server succeeded
# 2021/11/16 16:26:23 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/11/16 16:26:23 Send process info logs to master server succeeded
# [2021-11-16T16:26:23.133768] Entering context manager injector.
# [2021-11-16T16:26:23.808488] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['split.py', '--exp_training_data', 'DatasetOutputConfig:Exp_Training_Data', '--exp_testing_data', 'DatasetOutputConfig:Exp_Testing_Data'])
# Script type = None
# [2021-11-16T16:26:23.815239] Entering Run History Context Manager.
# [2021-11-16T16:26:24.617706] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82
# [2021-11-16T16:26:24.617798] Preparing to call script [split.py] with arguments:['--exp_training_data', '$Exp_Training_Data', '--exp_testing_data', '$Exp_Testing_Data']
# [2021-11-16T16:26:24.617827] After variable expansion, calling script [split.py] with arguments:['--exp_training_data', '/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Training_Data_workspaceblobstore', '--exp_testing_data', '/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Testing_Data_workspaceblobstore']
#
# 2021/11/16 16:26:27 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Index(['PatientID', 'Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure',
#        'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age',
#        'Diabetic'],
#       dtype='object')
#
#
# [2021-11-16T16:26:34.567224] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.13115453720092773 seconds
# [2021-11-16T16:26:34.856215] Finished context manager injector.
# 2021/11/16 16:26:40 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/11/16 16:26:40 Send process info logs to master server succeeded
# 2021/11/16 16:26:40 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/11/16 16:26:40 Process Exiting with Code:  0
# 2021/11/16 16:26:40 All App Insights Logs was sent successfully or the close timeout of 10 was reached
#
# Streaming azureml-logs/75_job_post-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ===============================================================================================================
# [2021-11-16T16:26:41.545914] Entering job release
# [2021-11-16T16:26:42.561257] Starting job release
# [2021-11-16T16:26:42.561839] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 307
# [2021-11-16T16:26:42.562508] job release stage : upload_datastore starting...
# [2021-11-16T16:26:42.580508] job release stage : start importing azureml.history._tracking in run_history_release.[2021-11-16T16:26:42.581004] Entering context manager injector.
# [2021-11-16T16:26:42.583914] job release stage : copy_batchai_cached_logs starting...[2021-11-16T16:26:42.584489] job release stage : upload_datastore completed...
#
#
# [2021-11-16T16:26:42.584980] job release stage : execute_job_release starting...
# [2021-11-16T16:26:42.585212] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:26:42.668631] job release stage : send_run_telemetry starting...
# [2021-11-16T16:26:42.691660] get vm size and vm region successfully.
# [2021-11-16T16:26:42.708257] get compute meta data successfully.
# [2021-11-16T16:26:42.825020] job release stage : execute_job_release completed...
# [2021-11-16T16:26:42.899314] post artifact meta request successfully.
# [2021-11-16T16:26:42.977845] upload compute record artifact successfully.
# [2021-11-16T16:26:42.977943] job release stage : send_run_telemetry completed...
# [2021-11-16T16:26:42.978348] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-11-16T16:26:42.978474] Running Sidecar release cmd...
# [2021-11-16T16:26:42.992169] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82
# [2021-11-16T16:26:43.005] Enter __exit__ of DatasetContextManager
# [2021-11-16T16:26:43.005] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Training_Data_workspaceblobstore.
# [2021-11-16T16:26:43.043] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Training_Data_workspaceblobstore.
# [2021-11-16T16:26:43.044] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Testing_Data_workspaceblobstore.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Testing_Data_workspaceblobstore: Invalid argument
# [2021-11-16T16:26:43.055] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/2dfc3702-d486-4ced-b6f6-1d4193a55c82/wd/Exp_Testing_Data_workspaceblobstore.
# [2021-11-16T16:26:43.056] Exit __exit__ of DatasetContextManager
# [2021-11-16T16:26:43.056056] Removing absolute paths from host...
# [2021-11-16T16:26:43.056385] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-11-16T16:26:43.803842] Ran Sidecar release cmd.
# [2021-11-16T16:26:43.803945] Job release is complete
# StepRun(Split  Raw Data) Execution Summary
# ===========================================
# StepRun( Split  Raw Data ) Status: Finished
# {'runId': '2dfc3702-d486-4ced-b6f6-1d4193a55c82', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:25:55.223992Z', 'endTimeUtc': '2021-11-16T16:26:53.978804Z', 'services': {}, 'properties': {'ContentSnapshotId': '7d8c19dd-2959-4a2c-a48d-383b8771e621', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'ad76a5ff-69b9-461a-b507-d8cd2af282ed', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'f6fec1b6', 'azureml.pipelinerunid': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipeline': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '6f49cc1b-22b4-45d3-ac07-ee58fb43fb13'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Exp_Raw_Data', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': '67e34741-2a49-4160-a82b-5ee41c70eeba', 'registeredId': '88bcdfeb-da9d-42e5-bc87-5859ef3e6afc', 'registeredVersion': '2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'Exp_Training_Data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'exp_training_data/2dfc3702-d486-4ced-b6f6-1d4193a55c82')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "67e34741-2a49-4160-a82b-5ee41c70eeba",
#     "name": "exp_Training_Data",
#     "version": 2,
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}, {'identifier': {'savedId': '7b0ffdf2-3c43-4cf4-9385-8e684809685b', 'registeredId': '260e37a3-540e-4544-9fea-75428a2bdbc8', 'registeredVersion': '2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'Exp_Testing_Data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'exp_testing_data/2dfc3702-d486-4ced-b6f6-1d4193a55c82')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "7b0ffdf2-3c43-4cf4-9385-8e684809685b",
#     "name": "exp_Testing_Data",
#     "version": 2,
#     "workspace": "Workspace.create(name='mm-aml-dev2', subscription_id='5da07161-3770-4a4b-aa43-418cbbb627cf', resource_group='mm-aml-dev2-rg')"
#   }
# }}], 'runDefinition': {'script': 'split.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--exp_training_data', 'DatasetOutputConfig:Exp_Training_Data', '--exp_testing_data', 'DatasetOutputConfig:Exp_Testing_Data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {}, 'data': {'Exp_Raw_Data': {'dataLocation': {'dataset': {'id': '6f49cc1b-22b4-45d3-ac07-ee58fb43fb13', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'Exp_Raw_Data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'Exp_Training_Data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'exp_training_data/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'exp_Training_Data', 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': '{\n  "blocks": [\n    {\n      "id": "bb9b04f0-e672-486a-b795-45937a8e1e8b",\n      "type": "Microsoft.DPrep.ParseDelimitedBlock",\n      "arguments": {\n        "columnHeadersMode": 3,\n        "fileEncoding": 0,\n        "handleQuotedLineBreaks": false,\n        "preview": false,\n        "separator": ",",\n        "skipRows": 0,\n        "skipRowsMode": 0\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    },\n    {\n      "id": "7f8010e3-9ba0-4a44-b90b-eb1fb1b68d03",\n      "type": "Microsoft.DPrep.DropColumnsBlock",\n      "arguments": {\n        "columns": {\n          "type": 0,\n          "details": {\n            "selectedColumns": [\n              "Path"\n            ]\n          }\n        }\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    }\n  ],\n  "inspectors": [],\n  "meta": {\n    "steps_added": "2"\n  }\n}'}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}, 'Exp_Testing_Data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'exp_testing_data/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'exp_Testing_Data', 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': '{\n  "blocks": [\n    {\n      "id": "205f0fe4-1937-41bf-a364-547def95ecbf",\n      "type": "Microsoft.DPrep.ParseDelimitedBlock",\n      "arguments": {\n        "columnHeadersMode": 3,\n        "fileEncoding": 0,\n        "handleQuotedLineBreaks": false,\n        "preview": false,\n        "separator": ",",\n        "skipRows": 0,\n        "skipRowsMode": 0\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    },\n    {\n      "id": "17326914-9f61-4bce-9698-1f0369265ee3",\n      "type": "Microsoft.DPrep.DropColumnsBlock",\n      "arguments": {\n        "columns": {\n          "type": 0,\n          "details": {\n            "selectedColumns": [\n              "Path"\n            ]\n          }\n        }\n      },\n      "localData": {},\n      "isEnabled": true,\n      "name": null,\n      "annotation": null\n    }\n  ],\n  "inspectors": [],\n  "meta": {\n    "steps_added": "2"\n  }\n}'}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn',  ...
# StepRunId: 520fcaf6-80e7-4379-9d3c-3f74160c1b05
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/520fcaf6-80e7-4379-9d3c-3f74160c1b05?wsid=/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourcegroups/mm-aml-dev2-rg/workspaces/mm-aml-dev2&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Train ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ========================================================================================================================
# 2021-11-16T16:27:55Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-16T16:27:55Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore
# 2021-11-16T16:27:55Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:55Z Starting output-watcher...
# 2021-11-16T16:27:55Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-16T16:27:56Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-11-16T16:27:56Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_21ec214220b650a356d20fde58334d25
# Digest: sha256:c162919178f51a2f8e4dfcd3d68b8b0eab6f5654b53ccab7345be1680ea6b670
# Status: Image is up to date for 9053afde19bd481fbc9ed12b3864a867.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:latest
# 9053afde19bd481fbc9ed12b3864a867.azurecr.io/azureml/azureml_21ec214220b650a356d20fde58334d25:latest
# 2021-11-16T16:27:56Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:27:56Z Check if container 520fcaf6-80e7-4379-9d3c-3f74160c1b05 already exist exited with 0,
#
# 1d455484ce2ee0ea7ceca16ab5980a0bd06d8408cc82769503ebefce03a3f718
# 2021-11-16T16:27:56Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-11-16T16:27:56Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2bb91b0022db20989cbebe19be25722d-7d18dcf547850ffe-01 -sshRequired=false]
# 2021/11/16 16:27:56 Got JobInfoJson from env
# 2021/11/16 16:27:56 Starting App Insight Logger for task:  containerSetup
# 2021/11/16 16:27:56 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# 2021/11/16 16:27:56 Entered ContainerSetupTask - Preparing infiniband
# 2021/11/16 16:27:56 Starting infiniband setup
# 2021/11/16 16:27:56 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/11/16 16:27:56 Returning Python Version as 3.6
# 2021-11-16T16:27:56Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:27:56 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:27:56 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/11/16 16:27:56 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021-11-16T16:27:56Z Not setting up Infiniband in Container
# 2021/11/16 16:27:56 Not setting up Infiniband in Container
# 2021/11/16 16:27:56 Not setting up Infiniband in Container
# 2021/11/16 16:27:56 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/11/16 16:27:56 Returning Python Version as 3.6
# 2021/11/16 16:27:56 sshd inside container not required for job, skipping setup.
# 2021/11/16 16:27:56 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/11/16 16:27:56 App Insight Client has already been closed
# 2021/11/16 16:27:56 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-11-16T16:27:56Z Starting docker container succeeded.
# 2021-11-16T16:28:00Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:00Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:28:01Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2021/11/16 16:27:54 Got JobInfoJson from env
# >>>   2021/11/16 16:27:54 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/11/16 16:27:54 Version: 3.0.01767.0003 Branch: .SourceBranch Commit: a360865
# >>>   2021/11/16 16:27:54 Got JobInfoJson from env
# >>>   2021/11/16 16:27:54 runtime.GOOS linux
# >>>   2021/11/16 16:27:54 Checking if '/tmp' exists
# >>>   2021/11/16 16:27:54 Reading dyanamic configs
# >>>   2021/11/16 16:27:54 Container sas url: https://baiscriptswestus2prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=71Fsy25bPMdce8Lc7jVPFZbJokMhH4i%2F250OyAEdREA%3D
# >>>   2021/11/16 16:27:55 Starting Azsecpack installation on machine: 796dd5eb985946b79258d71435a6e3b7000001#72f988bf-86f1-41af-91ab-2d7cd011db47#5da07161-3770-4a4b-aa43-418cbbb627cf#mm-aml-dev2-rg#mm-aml-dev2#mm-cluster#tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d
# >>>   2021/11/16 16:27:55 Azsecpack installation directory: /mnt/batch/tasks/startup/wd/az_resource, Is Azsecpack installer on host: true. Is Azsecpack installation enabled: true,AzSecPack_RoleInstance="diagnosticserver-5bfc9d86b5-2q4sp"
# >>>   2021/11/16 16:27:55 Is Azsecpack enabled: true, GetDisableVsatlsscan: true
# >>>   2021/11/16 16:27:55 Start preparing environment for azsecpack installation. MachineName is 796dd5eb985946b79258d71435a6e3b7000001
# >>>
# >>>   2021/11/16 16:27:55
# >>>   2021/11/16 16:27:55
# >>>   2021/11/16 16:27:55 bypass systemd resolved
# >>>   2021/11/16 16:27:55 Cluster Subscription Id: 5da07161-3770-4a4b-aa43-418cbbb627cf
# >>>   2021/11/16 16:27:55 Cluster Workspace Name: mm-aml-dev2
# >>>   2021/11/16 16:27:55 Cluster Name: mm-cluster
# >>>   2021/11/16 16:27:55 VMsize: standard_ds11_v2
# >>>   2021/11/16 16:27:55 GPU Count: 0
# >>>   2021/11/16 16:27:55 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/11/16 16:27:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:27:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:27:55 Get GPU count failed with err: The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.,
# >>>   2021/11/16 16:27:55 AMLComputeXDSEndpoint:  https://westus2.cert.api.azureml.ms/xdsbatchai
# >>>   2021/11/16 16:27:55 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/11/16 16:27:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/config
# >>>   2021/11/16 16:27:55 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/11/16 16:27:55 Starting identity responder.
# >>>   2021/11/16 16:27:55 Starting identity responder.
# >>>   2021/11/16 16:27:55 Logfile used for identity responder: /mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/520fcaf6-80e7-4379-9_5b9137ea-3d53-45a2-a919-50de80fe75c8/IdentityResponderLog-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# >>>   2021/11/16 16:27:55 Logfile used for identity responder: /mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/520fcaf6-80e7-4379-9_5b9137ea-3d53-45a2-a919-50de80fe75c8/IdentityResponderLog-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# >>>   2021/11/16 16:27:55 Started Identity Responder for job.
# >>>   2021/11/16 16:27:55 Started Identity Responder for job.
# >>>   2021/11/16 16:27:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/wd
# >>>   2021/11/16 16:27:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/shared
# >>>   2021/11/16 16:27:55 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# >>>   2021/11/16 16:27:55 From the policy service, the filtering patterns is: , data store is
# >>>   2021/11/16 16:27:55 Mounting job level file systems
# >>>   2021/11/16 16:27:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts
# >>>   2021/11/16 16:27:55 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/config/.amlcompute.datastorecredentials
# >>>   2021/11/16 16:27:55 Datastore credentials file not found, skipping.
# >>>   2021/11/16 16:27:55 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/config/.master.runtimesastokens
# >>>   2021/11/16 16:27:55 Runtime sas tokens file not found, skipping.
# >>>   2021/11/16 16:27:55 NFS mount is not enabled
# >>>   2021/11/16 16:27:55 No Azure File Shares configured
# >>>   2021/11/16 16:27:55 Mounting blob file systems
# >>>   2021/11/16 16:27:55 Blobfuse runtime version 1.3.6
# >>>   2021/11/16 16:27:55 Mounting azureml-blobstore-9053afde-19bd-481f-bc9e-d12b3864a867 container from mmamldev24709630538 account at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore
# >>>   2021/11/16 16:27:55 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/11/16 16:27:55 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/11/16 16:27:55 Blobfuse cache size set to 18154 MB.
# >>>   2021/11/16 16:27:55 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=18154 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/11/16 16:27:55 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore
# >>>   2021/11/16 16:27:55 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore
# >>>   2021/11/16 16:27:55 Successfully mounted azureml-blobstore-9053afde-19bd-481f-bc9e-d12b3864a867 container from mmamldev24709630538 account at /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore
# >>>   2021/11/16 16:27:55 Created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/mounts/workspaceblobstore/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# >>>   2021/11/16 16:27:55 No unmanaged file systems configured
# >>>   2021/11/16 16:27:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:27:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:27:55 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# >>>   2021/11/16 16:27:55 From the policy service, the filtering patterns is: , data store is
# >>>   2021/11/16 16:27:55 Creating working directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/wd/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# >>>   2021/11/16 16:27:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/wd/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# >>>   2021/11/16 16:27:55 Changing permissions for all existing files under directory: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/wd/azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05
# ...
# >>>   2021/11/16 16:29:27 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/wd/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/azureml_compute_logs/65_job_prep-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# >>>   2021/11/16 16:29:27 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/wd/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/azureml_compute_logs/65_job_prep-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# >>>   2021/11/16 16:29:27 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/c51806c8-9991-4530-a_1a544bc1-96e4-482f-a6aa-87c08db3d7da/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/wd/azureml/c51806c8-9991-4530-a0f8-a979944fd17b;/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/mounts/workspaceblobstore/azureml/c51806c8-9991-4530-a0f8-a979944fd17b-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"7d8c19dd-2959-4a2c-a48d-383b8771e621","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/16 16:29:27 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/11/16 16:29:27 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-bea56f365eb003553c8c573c2e3a44a8-17c55d8037e29169-01 -t c51806c8-9991-4530-a0f8-a979944fd17b bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6eed6f66-df05-4372-ad78-7c46165670d3/job-1/c51806c8-9991-4530-a_1a544bc1-96e4-482f-a6aa-87c08db3d7da/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/wd/azureml/c51806c8-9991-4530-a0f8-a979944fd17b;/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mm-aml-dev2/azureml/c51806c8-9991-4530-a0f8-a979944fd17b/mounts/workspaceblobstore/azureml/c51806c8-9991-4530-a0f8-a979944fd17b-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"7d8c19dd-2959-4a2c-a48d-383b8771e621","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/16 16:29:29 Attempt 1 of http call to https://westus2.api.azureml.ms/history/v1.0/private/subscriptions/5da07161-3770-4a4b-aa43-418cbbb627cf/resourceGroups/mm-aml-dev2-rg/providers/Microsoft.MachineLearningServices/workspaces/mm-aml-dev2/runs/c51806c8-9991-4530-a0f8-a979944fd17b/spans
# >>>   2021/11/16 16:29:31 containerName:c51806c8-9991-4530-a0f8-a979944fd17b
# >>>   2021/11/16 16:29:31 sidecar containerName:c51806c8-9991-4530-a0f8-a979944fd17b
# >>>   2021/11/16 16:29:32 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/16 16:29:32 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:29:32 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:29:32 sidecar dockerLauncher:docker
# >>>   2021/11/16 16:29:32 sidecarContainerId:f3e0127c2dd9e7a1bfbf1e9b8b5813b49b73e4135bc32a21251246fc7d360ee9
# >>>   2021/11/16 16:29:32 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/16 16:29:32 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:29:32 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/16 16:29:32 Docker logs for c51806c8-9991-4530-a0f8-a979944fd17b
# >>>
# >>>   2021/11/16 16:29:32 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:28.254935] Entering job preparation.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.573895] Starting job preparation.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.573938] Extracting the control code.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.574441] Starting extract_project.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.574505] Starting to extract zip file.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.599058] Finished extracting zip file.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.604074] Using urllib.request Python 3.0 or later
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.604173] Start fetching snapshots.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.604268] Start fetching snapshot.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:30.604297] Retrieving project from snapshot: 7d8c19dd-2959-4a2c-a48d-383b8771e621
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 43
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.001051] Finished fetching snapshot.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.001154] Finished fetching snapshots.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.001230] Finished extract_project.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.001589] Finished fetching and extracting the control code.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.011341] Start run_history_prep.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.011760] downloadDataStore - Download from datastores if requested.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.043894] Entering context manager injector.
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: Acquired lockfile /tmp/c51806c8-9991-4530-a0f8-a979944fd17b-datastore.lock to downloading input data references
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.699689] downloadDataStore completed
# >>>   2021/11/16 16:29:32 runSpecialJobTask: preparation: [2021-11-16T16:29:31.703587] Job preparation is complete.
# >>>   2021/11/16 16:29:32 DockerSideCarContainerLogs:
# >>>
# >>>   2021/11/16 16:29:32 DockerSideCarContainerLogs End
# >>>   2021/11/16 16:29:32 Execution of runSpecialJobTask completed
# >>>   2021/11/16 16:29:32 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/11/16 16:29:32 Process Exiting with Code:  0
# >>>   2021/11/16 16:29:32 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-11-16T16:29:32Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:29:32Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-16T16:29:32Z 127.0.0.1 slots=2 max-slots=2
# 2021-11-16T16:29:33Z launching Custom job
# 2021-11-16T16:29:38Z job exited with code 0
# 2021-11-16T16:29:39Z Executing 'JobRelease task' on 10.0.0.5
# Streaming azureml-logs/75_job_post-tvmps_3f38fe6a2e2b2d50a57c30cd65f0e09b774353f334fff87c50398ba50db6f17d_d.txt
# ===============================================================================================================
# [2021-11-16T16:29:40.005657] Entering job release
# [2021-11-16T16:29:41.317084] Starting job release
# [2021-11-16T16:29:41.318396] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 130
# [2021-11-16T16:29:41.320123] job release stage : upload_datastore starting...
# [2021-11-16T16:29:41.321358] Entering context manager injector.
# [2021-11-16T16:29:41.326690] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-16T16:29:41.336552] job release stage : execute_job_release starting...
# [2021-11-16T16:29:41.359810] job release stage : copy_batchai_cached_logs starting...
# [2021-11-16T16:29:41.361988] job release stage : copy_batchai_cached_logs completed...
# [2021-11-16T16:29:41.366473] job release stage : upload_datastore completed...
# [2021-11-16T16:29:41.434173] job release stage : send_run_telemetry starting...
# [2021-11-16T16:29:41.457147] get vm size and vm region successfully.
# [2021-11-16T16:29:41.487638] get compute meta data successfully.
# [2021-11-16T16:29:41.657102] post artifact meta request successfully.
# [2021-11-16T16:29:41.678116] job release stage : execute_job_release completed...
# [2021-11-16T16:29:41.709478] upload compute record artifact successfully.
# [2021-11-16T16:29:41.710179] job release stage : send_run_telemetry completed...
# [2021-11-16T16:29:41.711036] Job release is complete
#
# StepRun(Evaluate and Register Model) Execution Summary
# =======================================================
# StepRun( Evaluate and Register Model ) Status: Finished
# {'runId': 'c51806c8-9991-4530-a0f8-a979944fd17b', 'target': 'mm-cluster', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:29:23.685864Z', 'endTimeUtc': '2021-11-16T16:29:52.310551Z', 'services': {}, 'properties': {'ContentSnapshotId': '7d8c19dd-2959-4a2c-a48d-383b8771e621', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'fcb4ca5c-4d2a-4dc1-b6d4-87e1687ed0e4', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'bb29b2a5', 'azureml.pipelinerunid': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipeline': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'evaluate_and_register.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--exp_trained_model_pipeline_data', '$AZUREML_DATAREFERENCE_exp_trained_model_pipeline_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mm-cluster', 'dataReferences': {'exp_trained_model_pipeline_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/520fcaf6-80e7-4379-9d3c-3f74160c1b05/exp_trained_model_pipeline_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}], 'name': 'azureml_0c5a9aa2def4b3c2501c1f40287a356b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': [], 'dataBricks': {'workers': 0, 'minimumWorkerCount': 0, 'maxMumWorkerCount': 0, 'sparkVersion': '4.0.x-scala2.11', 'nodeTypeId': 'Standard_D3_v2', ' ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '353eb952-7a5a-4315-b01c-93e38bcd2b56', 'status': 'Completed', 'startTimeUtc': '2021-11-16T16:20:36.444555Z', 'endTimeUtc': '2021-11-16T16:29:53.520925Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.353eb952-7a5a-4315-b01c-93e38bcd2b56/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=T%2FiKd3fo8EvxhTJ9WwZQ78bA26zPZF1jZxE4h9DKPo4%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A54Z&se=2021-11-17T00%3A29%3A54Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.353eb952-7a5a-4315-b01c-93e38bcd2b56/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=qqbGW%2BqWu1K8IWfTEUAVABFUNgMl4yQswlDdwB8RP7A%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A54Z&se=2021-11-17T00%3A29%3A54Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mmamldev24709630538.blob.core.windows.net/azureml/ExperimentRun/dcid.353eb952-7a5a-4315-b01c-93e38bcd2b56/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=lieGpzama0X8FtLCj%2FLQsfFlBie%2FmZt6jNbzhZzOhXU%3D&skoid=b7a3bef5-d355-4fee-9d06-a4a027869af0&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-16T15%3A23%3A14Z&ske=2021-11-17T23%3A33%3A14Z&sks=b&skv=2019-07-07&st=2021-11-16T16%3A19%3A54Z&se=2021-11-17T00%3A29%3A54Z&sp=r'}, 'submittedBy': 'Megan Masanz'}
# 'Finished'

# %% [markdown]
# ## Publish Pipeline

# %%
published_pipeline = pipeline.publish(name = 'Diabetes Training Pipeline',
                                     description = 'Pipeline that generates batch predictions using a registered trained model.',
                                     continue_on_step_failure = False)

# %%
published_pipeline

# %%
# from azureml.pipeline.core import ScheduleRecurrence, Schedule

# # Submit the Pipeline every Monday at 00:00 UTC
# recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
# weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
#                                   description="Based on time",
#                                   pipeline_id=published_pipeline.id, 
#                                   experiment_name='mslearn-diabetes-pipeline', 
#                                   recurrence=recurrence)
# print('Pipeline scheduled.')
